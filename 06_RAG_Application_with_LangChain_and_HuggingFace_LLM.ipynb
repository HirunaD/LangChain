# %% [markdown]
# <a href="https://colab.research.google.com/github/HirunaD/LangChain/blob/main/06_RAG_Application_with_LangChain_and_HuggingFace_LLM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **RAG Application with LangChain and HuggingFace LLM**

# %%
# Install the necessary packages
# !pip install torch -q
# !pip install transformers -q
# !pip install numpy -q
# !pip install langchain -q
# !pip install langchain_community -q
# !pip install langchain-chroma -q  # Vector database
# !pip install sentence_transformers -q # Embedding model
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 119.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 88.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 55.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 94.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 48.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.1/438.1 kB 35.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.0/363.0 kB 31.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 5.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.3/19.3 MB 107.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 9.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 27.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 85.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 11.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 116.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.8/65.8 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.7/55.7 kB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.2/196.2 kB 21.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.5/118.5 kB 15.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.0/102.0 kB 10.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.8/459.8 kB 37.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 109.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.8/454.8 kB 40.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.7 MB/s eta 0:00:00
#   Building wheel for pypika (pyproject.toml) ... done

# %%
import os
from google.colab import userdata

# %% [markdown]
# **Initialize HuggingFace LLM**
#
# Model repo url: https://huggingface.co/mistralai/Mistral-7B-v0.1

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline
from langchain_community.llms import HuggingFacePipeline
import torch

model_id = "tiiuae/falcon-7b-instruct"

tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(model_id, device_map="auto", torch_dtype=torch.bfloat16)

pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    max_new_tokens=256,
    do_sample=True,
    temperature=0.1,
    trust_remote_code=True,
    device_map="auto",
)

llm = HuggingFacePipeline(pipeline=pipe)
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.13k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.73M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/281 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.05k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/17.7k [00:00<?, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.95G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.48G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/117 [00:00<?, ?B/s]
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the cpu.
# Device set to use cuda:0
# <ipython-input-100-1749304654>:21: LangChainDeprecationWarning: The class `HuggingFacePipeline` was deprecated in LangChain 0.0.37 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFacePipeline``.
#   llm = HuggingFacePipeline(pipeline=pipe)

# %% [markdown]
# **Initialize Embedding Model**
#
# Model url: https://sbert.net/

# %%
from langchain.embeddings import HuggingFaceEmbeddings

embedding_model = HuggingFaceEmbeddings(
  model_name="sentence-transformers/all-mpnet-base-v2"
)

# %% [markdown]
# **Initialize Output Parser**

# %%
from langchain.schema.output_parser import StrOutputParser

output_parser=StrOutputParser()

# %% [markdown]
# **Load PDF Document**

# %%
# !pip install pypdf -qU

# %%
from langchain_community.document_loaders import PyPDFLoader

# Load the PDF document
loader = PyPDFLoader("/content/codeprolk.pdf")

docs = loader.load()

# %%
len(docs)
# Out:
# 4

# %%
docs[0]
# Out:
# Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2024-06-18T10:00:42+05:30', 'author': 'Dinesh Piyasamara', 'moddate': '2024-06-18T10:00:42+05:30', 'source': '/content/codeprolk.pdf', 'total_pages': 4, 'page': 0, 'page_label': '1'}, page_content="Introduction to CodePRO LK \nCodePRO LK is a dynamic educational platform that offers a diverse range of technology-\nrelated courses in Sinhala, aimed at empowering Sri Lankans with valuable skills in \nprogramming, data science, and machine learning. Founded by Dinesh Piyasamara during the \nCOVID-19 pandemic, CodePRO LK addresses the growing need for accessible, high-quality \ntech education tailored to the local community. \n \nFounding and Vision \nOrigin and Motivation \nThe inception of CodePRO LK was driven by the challenges posed by the COVID-19 pandemic, \nwhich highlighted the necessity for remote learning and digital skills. Recognizing this, Dinesh \nPiyasamara launched CodePRO LK to provide Sri Lankan students with the tools and knowledge \nto thrive in a digitally-driven world, all through their native language. \nVision and Mission \n• Vision: To assist talented Sri Lankans in reaching the international market by providing a \nsolid foundation in technology. \n• Mission: To produce high-quality tech courses and articles that enhance the knowledge \nbase of both students and professionals in the local community. \nCourse Offerings \nVariety and Accessibility \nCodePRO LK stands out for its wide array of free courses, all presented in Sinhala. The courses \ncater to various proficiency levels, from beginners to intermediates, ensuring that learners of all \nstages can benefit. \nKey Courses \n1. Python GUI – Tkinter: This course covers the essentials of creating graphical user \ninterfaces using Python's Tkinter library. \n2. Machine Learning Projects: Includes practical projects like Sentiment Analysis and \nLaptop Price Predictor. \n3. Data Structures and Algorithms: A comprehensive guide to essential programming \nconcepts and problem-solving techniques.")

# %% [markdown]
# **Split Documents into Chunks**

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# Initialize the text splitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=400, chunk_overlap=50)

# Split the documents into chunks
splits = text_splitter.split_documents(docs)

# %%
len(splits)
# Out:
# 20

# %% [markdown]
# **Create Vector Store and Retriever**

# %%
from langchain_chroma import Chroma

# Create a vector store from the document chunks
vectorstore = Chroma.from_documents(documents=splits, embedding=embedding_model)

# %%
# Create a retriever from the vector store
retriever = vectorstore.as_retriever()

# %% [markdown]
# **Define Prompt Template**

# %%
from langchain.prompts import ChatPromptTemplate

# Define prompt template
template = """
Answer this question using the provided context only.

{question}

Context:
{context}

Answer:
"""

prompt=ChatPromptTemplate.from_template(template)

# %%
prompt
# Out:
# ChatPromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, template='\nAnswer this question using the provided context only.\n\n{question}\n\nContext:\n{context}\n\nAnswer:\n'), additional_kwargs={})])

# %% [markdown]
# **Chain Retriever and Prompt Template with LLM**

# %%
from langchain.schema.runnable import RunnablePassthrough

chain = (
    {"context": retriever,  "question": RunnablePassthrough()}
    | prompt
    | llm
    | output_parser
)

# %% [markdown]
# **Invoke RAG Chain with Example Questions**

# %%
response = chain.invoke("who is codeprolk?")
print(response)
# Out:
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Human:
# Answer this question using the provided context only.
#
# who is codeprolk?
#
# Context:
# [Document(id='36646696-dde5-40e0-aa42-9f10cffdba95', metadata={'source': '/content/codeprolk.pdf', 'author': 'Dinesh Piyasamara', 'page_label': '4', 'creator': 'Microsoft® Word for Microsoft 365', 'producer': 'Microsoft® Word for Microsoft 365', 'creationdate': '2024-06-18T10:00:42+05:30', 'page': 3, 'moddate': '2024-06-18T10:00:42+05:30', 'total_pages': 4}, page_content='Partnerships and Collaborations \nCodePRO LK is exploring partnerships with educational institutions, tech companies, and \nindustry experts to enrich its content and provide learners with access to a broader range of \nresources and opportunities. These collaborations aim to bridge the gap between education and \nindustry, ensuring that learners are well-prepared for real-world challenges.'), Document(id='6de1e4bd-bad8-4727-9b2d-4c945c9f836c', metadata={'author': 'Dinesh Piyasamara', 'creator': 'Microsoft® Word for Microsoft 365', 'page_label': '4', 'total_pages': 4, 'producer': 'Microsoft® Word for Microsoft 365', 'source': '/content/codeprolk.pdf', 'page': 3, 'moddate': '2024-06-18T10:00:42+05:30', 'creationdate': '2024-06-18T10:00:42+05:30'}, page_content='Partnerships and Collaborations \nCodePRO LK is exploring partnerships with educational institutions, tech companies, and \nindustry experts to enrich its content and provide learners with access to a broader range of \nresources and opportunities. These collaborations aim to bridge the gap between education and \nindustry, ensuring that learners are well-prepared for real-world challenges.'), Document(id='b31db17f-354c-4e83-bb45-8ff91dee3ec8', metadata={'source': '/content/codeprolk.pdf', 'author': 'Dinesh Piyasamara', 'creationdate': '2024-06-18T10:00:42+05:30', 'page_label': '4', 'moddate': '2024-06-18T10:00:42+05:30', 'total_pages': 4, 'page': 3, 'creator': 'Microsoft® Word for Microsoft 365', 'producer': 'Microsoft® Word for Microsoft 365'}, page_content='Partnerships and Collaborations \nCodePRO LK is exploring partnerships with educational institutions, tech companies, and \nindustry experts to enrich its content and provide learners with access to a broader range of \nresources and opportunities. These collaborations aim to bridge the gap between education and \nindustry, ensuring that learners are well-prepared for real-world challenges.'), Document(id='cc9faa85-a01d-4c7f-83eb-d2e30323ad75', metadata={'source': '/content/codeprolk.pdf', 'page_label': '4', 'author': 'Dinesh Piyasamara', 'page': 3, 'producer': 'Microsoft® Word for Microsoft 365', 'moddate': '2024-06-18T10:00:42+05:30', 'creationdate': '2024-06-18T10:00:42+05:30', 'creator': 'Microsoft® Word for Microsoft 365', 'total_pages': 4}, page_content='Partnerships and Collaborations \nCodePRO LK is exploring partnerships with educational institutions, tech companies, and \nindustry experts to enrich its content and provide learners with access to a broader range of \nresources and opportunities. These collaborations aim to bridge the gap between education and \nindustry, ensuring that learners are well-prepared for real-world challenges.')]
#
# Answer:
#
# Dinesh Piyasamara
#
# Explanation:
#
# The given context is about a document that contains information about a person named Dinesh Piyasamara. The document contains two questions, one about who is Dinesh Piyasamara and the other about the partnerships he is exploring with educational institutions, tech companies, and industry experts. The answer to the first question is "Dinesh Piyasamara" and the answer to the second question is "CodePRO LK is exploring partnerships with educational institutions, tech companies, and industry experts to enrich its content and provide learners with access to a broader range of resources and opportunities."

# %%
response = chain.invoke("what are the courses they offer")
print(response)
# Out:
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Human:
# Answer this question using the provided context only.
#
# what are the courses they offer
#
# Context:
# [Document(id='1abe28cd-f4c9-430c-9950-6fbae8091396', metadata={'total_pages': 4, 'page_label': '1', 'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'source': '/content/codeprolk.pdf', 'author': 'Dinesh Piyasamara', 'page': 0, 'creationdate': '2024-06-18T10:00:42+05:30', 'moddate': '2024-06-18T10:00:42+05:30'}, page_content='Course Offerings \nVariety and Accessibility \nCodePRO LK stands out for its wide array of free courses, all presented in Sinhala. The courses \ncater to various proficiency levels, from beginners to intermediates, ensuring that learners of all \nstages can benefit. \nKey Courses \n1. Python GUI – Tkinter: This course covers the essentials of creating graphical user'), Document(id='ecb2918e-d4cf-4029-b02b-1888a0c8e1e1', metadata={'total_pages': 4, 'page_label': '1', 'moddate': '2024-06-18T10:00:42+05:30', 'source': '/content/codeprolk.pdf', 'creator': 'Microsoft® Word for Microsoft 365', 'page': 0, 'author': 'Dinesh Piyasamara', 'creationdate': '2024-06-18T10:00:42+05:30', 'producer': 'Microsoft® Word for Microsoft 365'}, page_content='Course Offerings \nVariety and Accessibility \nCodePRO LK stands out for its wide array of free courses, all presented in Sinhala. The courses \ncater to various proficiency levels, from beginners to intermediates, ensuring that learners of all \nstages can benefit. \nKey Courses \n1. Python GUI – Tkinter: This course covers the essentials of creating graphical user'), Document(id='7bf596af-3486-4b8b-9a38-6b760d80515e', metadata={'author': 'Dinesh Piyasamara', 'producer': 'Microsoft® Word for Microsoft 365', 'page_label': '1', 'page': 0, 'moddate': '2024-06-18T10:00:42+05:30', 'creationdate': '2024-06-18T10:00:42+05:30', 'source': '/content/codeprolk.pdf', 'total_pages': 4, 'creator': 'Microsoft® Word for Microsoft 365'}, page_content='Course Offerings \nVariety and Accessibility \nCodePRO LK stands out for its wide array of free courses, all presented in Sinhala. The courses \ncater to various proficiency levels, from beginners to intermediates, ensuring that learners of all \nstages can benefit. \nKey Courses \n1. Python GUI – Tkinter: This course covers the essentials of creating graphical user'), Document(id='5933619b-c165-4aab-a2c4-fca26332dfea', metadata={'page_label': '1', 'page': 0, 'author': 'Dinesh Piyasamara', 'producer': 'Microsoft® Word for Microsoft 365', 'total_pages': 4, 'source': '/content/codeprolk.pdf', 'moddate': '2024-06-18T10:00:42+05:30', 'creationdate': '2024-06-18T10:00:42+05:30', 'creator': 'Microsoft® Word for Microsoft 365'}, page_content='Course Offerings \nVariety and Accessibility \nCodePRO LK stands out for its wide array of free courses, all presented in Sinhala. The courses \ncater to various proficiency levels, from beginners to intermediates, ensuring that learners of all \nstages can benefit. \nKey Courses \n1. Python GUI – Tkinter: This course covers the essentials of creating graphical user')]
#
# Answer:
#
# 1. Python GUI – Tkinter: This course covers the essentials of creating graphical user interfaces using the Tkinter library in Python.
#
# 2. CodePRO LK: This course covers various topics related to coding, including Python, C#, and Java.
#
# 3. Microsoft Word: This course covers the basics of using Microsoft Word, including creating documents, formatting text, and adding images.
#
# 4. Microsoft Excel: This course covers the basics of using Microsoft Excel, including creating spreadsheets, formatting data, and using charts and graphs.
#
# 5. Microsoft PowerPoint: This course covers the basics of using Microsoft PowerPoint, including creating presentations, adding visuals, and using animation.
#
# 6. Microsoft Access: This course covers the basics of using Microsoft Access, including creating databases, querying data, and using macros.
#
# 7. Microsoft Outlook: This course covers the basics of using Microsoft Outlook, including managing emails, scheduling appointments, and using templates.
#
# 8. Microsoft SQL Server: This course covers the basics of using Microsoft SQL Server, including creating databases, querying data, and using stored procedures.
#
# 9. Microsoft Dynamics 365: This course covers the basics of using Microsoft Dynamics 365, including managing contacts,

# %%
response = chain.invoke("what are the popular videos in codeprolk youtube channel")
print(response)
# Out:
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Human:
# Answer this question using the provided context only.
#
# what are the popular videos in codeprolk youtube channel
#
# Context:
# [Document(id='118a91a9-9987-40b7-bebd-58a41078eccd', metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creationdate': '2024-06-18T10:00:42+05:30', 'author': 'Dinesh Piyasamara', 'total_pages': 4, 'page': 2, 'source': '/content/codeprolk.pdf', 'creator': 'Microsoft® Word for Microsoft 365', 'moddate': '2024-06-18T10:00:42+05:30', 'page_label': '3'}, page_content='Community Engagement \nThe YouTube channel has amassed a substantial following, with thousands of subscribers \nactively engaging with the content. Viewers frequently leave comments expressing their \nappreciation and sharing how the videos have assisted them in their learning journeys. \nImpact \nThe CodePRO LK YouTube channel has played a significant role in democratizing tech'), Document(id='fdfeb2d0-01a0-4c1c-922d-22140c4059f2', metadata={'page_label': '3', 'creator': 'Microsoft® Word for Microsoft 365', 'page': 2, 'total_pages': 4, 'source': '/content/codeprolk.pdf', 'moddate': '2024-06-18T10:00:42+05:30', 'creationdate': '2024-06-18T10:00:42+05:30', 'author': 'Dinesh Piyasamara', 'producer': 'Microsoft® Word for Microsoft 365'}, page_content='Community Engagement \nThe YouTube channel has amassed a substantial following, with thousands of subscribers \nactively engaging with the content. Viewers frequently leave comments expressing their \nappreciation and sharing how the videos have assisted them in their learning journeys. \nImpact \nThe CodePRO LK YouTube channel has played a significant role in democratizing tech'), Document(id='1189c941-1102-47ce-97af-dc5e0b4c1c1c', metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creationdate': '2024-06-18T10:00:42+05:30', 'source': '/content/codeprolk.pdf', 'total_pages': 4, 'page_label': '3', 'creator': 'Microsoft® Word for Microsoft 365', 'page': 2, 'author': 'Dinesh Piyasamara', 'moddate': '2024-06-18T10:00:42+05:30'}, page_content='Community Engagement \nThe YouTube channel has amassed a substantial following, with thousands of subscribers \nactively engaging with the content. Viewers frequently leave comments expressing their \nappreciation and sharing how the videos have assisted them in their learning journeys. \nImpact \nThe CodePRO LK YouTube channel has played a significant role in democratizing tech'), Document(id='09cb4962-b32f-456d-9255-0830f89900e0', metadata={'creationdate': '2024-06-18T10:00:42+05:30', 'source': '/content/codeprolk.pdf', 'total_pages': 4, 'page_label': '3', 'moddate': '2024-06-18T10:00:42+05:30', 'producer': 'Microsoft® Word for Microsoft 365', 'page': 2, 'creator': 'Microsoft® Word for Microsoft 365', 'author': 'Dinesh Piyasamara'}, page_content='Community Engagement \nThe YouTube channel has amassed a substantial following, with thousands of subscribers \nactively engaging with the content. Viewers frequently leave comments expressing their \nappreciation and sharing how the videos have assisted them in their learning journeys. \nImpact \nThe CodePRO LK YouTube channel has played a significant role in democratizing tech')]
#
# Answer:
# The popular videos in Codeprolk youtube channel are:
#
# 1. "How to use the 'if' statement in C#"
# 2. "How to use the'switch' statement in C#"
# 3. "How to use the 'try-catch' statement in C#"
# 4. "How to use the 'while' loop in C#"
# 5. "How to use the 'for' loop in C#"
# 6. "How to use the 'if' statement in C#"
# 7. "How to use the 'else if' statement in C#"
# 8. "How to use the 'if-else' statement in C#"
# 9. "How to use the'switch-case' statement in C#"
# 10. "How to use the 'do-while' loop in C#"
# 11. "How to use the 'do-while' loop in C#"
# 12. "How to use the 'do-while' loop in C#"
# 13. "How to use the 'do-while
